# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, classification_report
from sklearn.preprocessing import StandardScaler


dataset = pd.read_csv('diabetes.csv')
print("\nshape of dataset:", dataset.shape)

print("\nmissing values:", dataset.isnull().sum())
# Out:
# shape of dataset: (768, 9)
#
# missing values: Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#joint plot of DiabetesPedigreeFunction against Age
sns.jointplot(x='DiabetesPedigreeFunction',y='Age',hue='Outcome',data=dataset,kind='scatter')

plt.show()

# %%
#joint plot of Insulin against BMI
sns.boxplot(x='Insulin',y='BMI',data=dataset)

plt.show()

# %%
sns.pairplot(dataset.select_dtypes(['number']),hue='Outcome')

# %%
#Scatterplot showing age against insuline
sns.scatterplot(x='Age', y='Insulin', data=dataset,hue='Outcome')
plt.title("Age vs Insulin")
plt.show()

# %%
dataset.head()
sns.scatterplot(x='Pregnancies', y='BloodPressure',hue='Outcome', data=dataset)
plt.title("Pregnancies vs BloodPressure")
plt.show()

# %%
#shows frequency of  Diabetes Pedigree Function
sns.histplot(dataset['DiabetesPedigreeFunction'],kde=True)
plt.title("Diabetics Pedigree")
plt.xlabel('DPF Value')
plt.ylabel('Frequency')
plt.show()

# %%
#show the dataset correlation through a heatmap
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
#split the Data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#train Logistic Regression Model
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#This code for accuracy
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 62.99%

# %%
#the confusion matrix code
print("Confusion Matrix::\n",confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix::
#  [[76 23]
#  [34 21]]
